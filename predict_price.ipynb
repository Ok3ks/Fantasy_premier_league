# %%
#utils 
import pandas as pd

# %%
file = "2021_player_data"

with open(file, 'r') as input:
    data = pd.read_csv(input)

pd.options.display.max_columns = None
data
# Out:
#      Unnamed: 0  chance_of_playing_next_round  chance_of_playing_this_round  \
# 0             0                         100.0                         100.0
# 1             1                           0.0                           0.0
# 2             2                           0.0                           0.0
# 3             3                           0.0                           0.0
# 4             4                         100.0                         100.0
# ..          ...                           ...                           ...
# 732         732                           0.0                           0.0
# 733         733                           NaN                           NaN
# 734         734                           0.0                           0.0
# 735         735                           0.0                           0.0
# 736         736                           NaN                           NaN
#
# ...

# %%
column_new = data[['code','element_type','id', 'first_name',
       'now_cost', 'points_per_game', #'team',
       'team_code', 'total_points', 
       #'value_form', 
       'value_season',
       'minutes', 'goals_scored', 'assists', 'clean_sheets',
       #'goals_conceded', 'penalties_saved', 'penalties_missed',
       #'yellow_cards', 'red_cards', 'saves', 
       'bonus', 'bps', 'influence',
       'creativity', 'threat', 'direct_freekicks_order',
       'penalties_order' ]]
column_new = column_new.fillna(0)

gk_df = column_new[column_new.element_type ==1]
defender_df = column_new[column_new.element_type ==2 ]
mid_df = column_new[column_new.element_type ==3 ]
striker_df = column_new[column_new.element_type ==4 ]

# %%
max(striker_df['penalties_order'])

X_features = mid_df['points_per_game', ]
# Out:
# 4.0

# %% [markdown]
# Cluster players to determine position. use heatmap to determine average position

# %% [markdown]
# Create model based on old data, using difference between old price and new price and season performance

# %%
mid_df
# Out:
#        code  element_type   id       first_name  now_cost  points_per_game  \
# 2     47431             3    3          Willian        63              0.0
# 6     84450             3    7           Granit        48              2.2
# 10   153256             3   12    Mohamed Naser        44              1.9
# 11   154043             3   13          Ainsley        52              1.5
# 13   167199             3   15           Thomas        50              3.0
# ..      ...           ...  ...              ...       ...              ...
# 725  245923             3  547             Luke        44              1.8
# 726  461026             3  548             Chem        44              1.0
# 732  428610             3  661      Bruno André        45              0.0
# 735  232351             3  687             Ryan        45              0.0
# 736  510363             3  689  Francisco Jorge        55              2.5
#
# ...
